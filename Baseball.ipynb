# %% [markdown]
# #               Baseball Case Study:

# %% [markdown]
# ## Problem Statement
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015season  based on several different indicators of success.There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
#    ##### Major league Baseball(MLB)  is a professional baseball organization              with a total of 30 teams in the United States and Canada which is Established in 1903

# %% [markdown]
# Input features :
#               Runs,AtBats,Hits,Doubles,Triples,Homeruns,Walks,Strikeouts,Stolen Bases,Runs Allowed,Earned Runs,Earned Run Average(ERA),Shutouts,Saves,Complete Games and Errors
#
# Output :Number of predicted wins(W)

# %% [markdown]
# # Importing dataset:

# %%
# importing required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# importing data 
df=pd.read_csv("BaseballCase.csv")

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
#  The dataset contains 16 features which contains the statistics summary of the baseball players
# and other one is our target variable.In this datasetm'W' is the target variable,which contains
# the number of predicted wins. Also we can see that the dataset contains only numerical value
# and no categorical data. So by observing the dataset and problem statement it's a Regression type problem

# %% [markdown]
#  lets rename the columns, in order to have easy understandings of each column

# %%
#renaming the columns

df.rename(columns = {'W':'Wins', 'R':'Runs', 'AB':'At_Bats', 'H':'Hits', '2B':'Doubles', '3B':'Triples', 
                       'HR':'Home_Runs', 'BB':'Walks', 'SO':'Strikeouts', 'SB':'Stolen_Bases', 'RA':'Runs_Allowed', 
                       'ER':'Earned_Runs', 'CG':'Complete_Games', 'SHO':'Shutouts', 'SV':'Saves', 'E':'Errors'},inplace = True)

# %%
df.head()
# Out:
#    Wins  Runs  At_Bats  Hits  Doubles  Triples  Home_Runs  Walks  Strikeouts  \
# 0    95   724     5575  1497      300       42        139    383         973
# 1    83   696     5467  1349      277       44        156    439        1264
# 2    81   669     5439  1395      303       29        141    533        1157
# 3    76   622     5533  1381      260       27        136    404        1231
# 4    74   689     5605  1515      289       49        151    455        1259
#
#    Stolen_Bases  Runs_Allowed  Earned_Runs   ERA  Complete_Games  Shutouts  \
# 0           104           641          601  3.73               2         8
# 1            70           700          653  4.07               2        12
# 2            86           640          584  3.67              11        10
# 3            68           701          643  3.98               7         9
# 4            83           803          746  4.64               7        12
#
#    Saves  Errors
# 0     56      88
# ...

# %%
df.columns
# Out:
# Index(['Wins', 'Runs', 'At_Bats', 'Hits', 'Doubles', 'Triples', 'Home_Runs',
#        'Walks', 'Strikeouts', 'Stolen_Bases', 'Runs_Allowed', 'Earned_Runs',
#        'ERA', 'Complete_Games', 'Shutouts', 'Saves', 'Errors'],
#       dtype='object')

# %% [markdown]
#  our column names are successfully changed

# %% [markdown]
# # Exploratory Data analysis(EDA)

# %%
#Checking the dimension of the dataset
df.shape
# Out:
# (30, 17)

# %% [markdown]
# In this dataset contains 30 rows and 17 columns (After checking the dimension of it)

# %%
# once again checking the column names 
df.columns
# Out:
# Index(['Wins', 'Runs', 'At_Bats', 'Hits', 'Doubles', 'Triples', 'Home_Runs',
#        'Walks', 'Strikeouts', 'Stolen_Bases', 'Runs_Allowed', 'Earned_Runs',
#        'ERA', 'Complete_Games', 'Shutouts', 'Saves', 'Errors'],
#       dtype='object')

# %% [markdown]
# Above all column names of my data set clearly understand by their fullforms i mention it

# %%
# Checking the data types of all columns
df.dtypes
# Out:
# Wins                int64
# Runs                int64
# At_Bats             int64
# Hits                int64
# Doubles             int64
# Triples             int64
# Home_Runs           int64
# Walks               int64
# Strikeouts          int64
# Stolen_Bases        int64
# Runs_Allowed        int64
# Earned_Runs         int64
# ERA               float64
# Complete_Games      int64
# Shutouts            int64
# Saves               int64
# Errors              int64
# dtype: object

# %% [markdown]
# In the above output  all columns are integer datatype other than ERA.
# ERA is the Float datatype

# %%
#Statistical Summary


df.isna().sum()
# Out:
# Wins              0
# Runs              0
# At_Bats           0
# Hits              0
# Doubles           0
# Triples           0
# Home_Runs         0
# Walks             0
# Strikeouts        0
# Stolen_Bases      0
# Runs_Allowed      0
# Earned_Runs       0
# ERA               0
# Complete_Games    0
# Shutouts          0
# Saves             0
# Errors            0
# dtype: int64

# %%
# lets me know the info about dataset and also checking it

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Wins            30 non-null     int64
#  1   Runs            30 non-null     int64
#  2   At_Bats         30 non-null     int64
#  3   Hits            30 non-null     int64
#  4   Doubles         30 non-null     int64
#  5   Triples         30 non-null     int64
#  6   Home_Runs       30 non-null     int64
#  7   Walks           30 non-null     int64
#  8   Strikeouts      30 non-null     int64
#  9   Stolen_Bases    30 non-null     int64
#  10  Runs_Allowed    30 non-null     int64
#  11  Earned_Runs     30 non-null     int64
#  12  ERA             30 non-null     float64
#  13  Complete_Games  30 non-null     int64
#  14  Shutouts        30 non-null     int64
#  15  Saves           30 non-null     int64
#  16  Errors          30 non-null     int64
# dtypes: float64(1), int64(16)
# ...

# %% [markdown]
# By the above output comeout we can easily know how much memory it utilized(usage)
# and which dtype is exist in that specific column and their is no null values are exist here

# %%
 # checking the number of unique values in each column
df.nunique()
# Out:
# Wins              24
# Runs              28
# At_Bats           29
# Hits              29
# Doubles           22
# Triples           23
# Home_Runs         27
# Walks             29
# Strikeouts        29
# Stolen_Bases      27
# Runs_Allowed      30
# Earned_Runs       30
# ERA               30
# Complete_Games     9
# Shutouts          12
# Saves             20
# Errors            21
# dtype: int64

# %%
# confirming the null values in the data frame by checking
df.isnull().sum()
# Out:
# Wins              0
# Runs              0
# At_Bats           0
# Hits              0
# Doubles           0
# Triples           0
# Home_Runs         0
# Walks             0
# Strikeouts        0
# Stolen_Bases      0
# Runs_Allowed      0
# Earned_Runs       0
# ERA               0
# Complete_Games    0
# Shutouts          0
# Saves             0
# Errors            0
# dtype: int64

# %% [markdown]
# Their is no missing values in the dataset, so it is cleared
# let visualize this by heat map

# %%
 # lets visualize the null values clearly
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Then it is clear there are no missing values present, now we can proceed further

# %%
# Checking the uniqueness of dataset 
df['Wins'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %% [markdown]
# The unique values are present in the target variable'Wins'.

# %%
# list of values in the target variable
df["Wins"].value_counts()
# Out:
# 68     3
# 83     2
# 74     2
# 76     2
# 81     2
# 64     1
# 93     1
# 92     1
# 90     1
# 88     1
# 87     1
# 86     1
# 85     1
# 84     1
# 80     1
# 97     1
# 100    1
# 78     1
# 63     1
# 79     1
# 71     1
# 67     1
# 98     1
# 95     1
# Name: Wins, dtype: int64

# %%
# Statistical summary of dataset
df.describe()
# Out:
#              Wins        Runs      At_Bats         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples   Home_Runs       Walks  Strikeouts  Stolen_Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# ...

# %% [markdown]
# In the summary statistics it has all numerical features and some of the features are not normally distributed

# %%
# visualizing the statistics of the columns using Heatmap
plt.figure(figsize=(16,9))
sns.heatmap(df.describe(),linewidths=0.2,fmt='0.2f',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The above Heatmap visualize shows the Statistics Summary of Dataset

# %% [markdown]
# # Visualization:

# %% [markdown]
# # Univariate Analysis(EDA):

# %%
 # Checking how the data is distributed in each column
plt.figure(figsize=(20,25), facecolor='white')
 plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.distplot(df[column],color='r')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# All most all columns are normally distributed.
# Except Runs,Strikeouts,Complete_Games,Errors

# %%
plt.figure(figsize=(20,30), facecolor='white')
plotnumber = 1

for column in df:
    if plotnumber<=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.boxplot(df[column],color='g')
        plt.xlabel(column,fontsize=30)
    plotnumber+=1
plt.show()

# %% [markdown]
# By observing the box plots we can observe the outliers are present in the columns
# 'Runs','ERA','Shutouts','Saves','Error'.we will remove these outliers using either Zscore or
# IQR method before building our machine learning models

# %% [markdown]
#    # Bivariate Analysis(EDA)

# %%
   # Checking the relation between two variables
plt.figure(figsize=[10,5])
plt.title('Comparsion between Runs and Shutouts')
sns.scatterplot(df['Runs'],df['Shutouts'],hue=df["Wins"]);
plt.xlabel("Runs")
plt.ylabel("Shoutouts")
# Out:
# Text(0, 0.5, 'Shoutouts')

# %% [markdown]
# This scatter plot gives the relation between Runs and Shutouts on the basis of Wins.
# The runs in between 650-700 we see highest number of shutouts where as the average
# shutouts takesplace  is 10-15 with in the range of 650-750.
# we can also see outliers presence in that.

# %%
 # Checking relation between two varaibles
plt.figure(figsize=[10,5])
plt.title('Comparsion between Runs and Hits')
sns.scatterplot(df['Runs'],df['Hits'],hue=df["Wins"],palette="husl");
plt.xlabel("Runs")
plt.ylabel("Hits")
# Out:
# Text(0, 0.5, 'Hits')

# %% [markdown]
# In these we can't see their is linearity between the columns.
# The rate of runs is high in the range of 630-780 with the rate of hits ranges 1500,which means the wins of the team
# is more in these ranges.

# %%
# checking the relation between two variables
plt.figure(figsize=[10,5])
plt.title('Comparsion between Hits and At_Bats')
sns.scatterplot(df['Hits'],df['At_Bats'],hue=df['Wins']);
plt.xlabel('Hits')
plt.ylabel('At_Bats')
# Out:
# Text(0, 0.5, 'At_Bats')

# %% [markdown]
# In these we can observe that maximum wins between 1460hits and 5640At_Bats.
# we can also see that most of wins happen between 1330-1400 range Hits with 5400-5600 At_Bats.

# %%
# checking the relation between two variables
plt.figure(figsize=[10,5])
plt.title('Comparsion between Runs and Errors')
sns.scatterplot(df['Runs'],df['Errors'],hue=df["Wins"]);
plt.xlabel('Runs')
plt.ylabel('Errors')
# Out:
# Text(0, 0.5, 'Errors')

# %% [markdown]
# In these plot their is no linear relationship between columns and we can infer that there is no correlation.
# the scatter plot give the relation between Runs and Errors on the basis of Wins.
# in these we can see the outliers also , the runs between 640-760 have errors upto max 100 has more wins.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,5])
plt.title('Comparsion between Triples and Wins')
sns.regplot(df['Triples'],df['Wins']);
plt.xlabel('Triples')
plt.ylabel('Wins')
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# In these i can observe a negative flow which is decreasing from wins to triples( following datamention.)

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,5])
plt.title('Comparsion between Runs and Wins')
sns.lineplot(df['Runs'],df['Wins'],color='y')
plt.xlabel("Runs")
plt.ylabel("Wins")
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# We can observe that the Runrate is high in the range 640-650 followed by the range of 740,
# so in this range the wins of team is also high. As the runrate increases the rate of wins also increases.

# %%
 # checking the realtion between two variables 
plt.figure(figsize=[10,5])
plt.title('Comparsion between Doubles and Triples')
sns.lineplot(df['Doubles'],df['Triples'],color='r')
plt.xlabel('Doubles')
plt.ylabel('Triples')
# Out:
# Text(0, 0.5, 'Triples')

# %% [markdown]
# we can observe that when their is maximum triples(20-48) which is followed to as well to Doubles(270-290).
# In starting which is decreasing from high to low (Triples) in the range of below 240- 265(Doubles)
# Overall we can observe the ups and downs when it flows through doubles and triples.

# %%
# Chwcking the realtion between two variables
plt.figure(figsize=[10,5])
plt.title('Comparsion between Runs_Allowed and Wins')
sns.regplot(df['Runs_Allowed'],df['Wins']);
plt.xlabel('Runs_Allowed')
plt.ylabel('Wins')
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# In these we can clearly observe that the target column has negative linear relationsip with feature Runs_Allowed,since data is falling from
# left to right which means labelis higly correlated with the feature.

# %%
# checcking the relation between two variables
plt.figure(figsize=[10,6])
plt.title('Comparsion between Earned Runs Average and Wins')
sns.lineplot(df['ERA'],df['Wins']);
plt.xlabel('ERA')
plt.ylabel('Wins')
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# In these their is negative linear relationship takes place when ERA increases the win
# rate is decreases and target is highly correlated with the feature.

# %%
# Checking the relation between two variables
plt.figure(figsize=[10,5])
plt.title('Comparsion between Saves and Wins')
sns.regplot(df['Saves'],df['Wins'],color='y');
plt.xlabel('Saves')
plt.ylabel('Wins')
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# In these we can observe that there is clearly positive linear relationship shows.
# The features are Saves and Wins,Also as the Saves increases wins also increases.

# %%
# checking the relation between two variables
plt.figure(figsize=[10,5])
plt.title('Comparsion between At_Bats and Errors')
sns.regplot(df['At_Bats'],df['Errors']);
plt.xlabel('At_Bats')
plt.ylabel('Errors')
# Out:
# Text(0, 0.5, 'Errors')

# %% [markdown]
# In these we can clearly observe that errors is increase when At_bats increase.

# %%
# Checking the relation between two variables 
plt.figure(figsize=[10,5])
plt.title('Comparsion between Stolen Bases and Wins')
sns.lineplot(df['Stolen_Bases'],df['Wins']);
plt.xlabel('Stolen_Bases')
plt.ylabel('Wins')
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# there is no linear relationship between these columns. the winning rate is high in the range
# 95-100(Stolen_Bases).

# %%
# Checking the relation between the two variables
plt.figure(figsize=[10,5])
plt.title('Comparsion between Complete_games and Wins')
sns.lineplot(df['Complete_Games'],df['Wins']);
plt.xlabel('Complete_Games')
plt.ylabel('Wins')
# Out:
# Text(0, 0.5, 'Wins')

# %% [markdown]
# In these there is not much  linear relationship betweeen columns.It had ups and downs
# it complete games over wins, and there is high wins of 88 at 6 complete games.

# %%
# checking the relation between two variables
plt.figure(figsize=[10,5])
plt.title('Comparsion between Walks and Strikeouts')
sns.lineplot(df['Walks'],df['Strikeouts']);
plt.xlabel('Walks')
plt.ylabel('Strikeouts')
# Out:
# Text(0, 0.5, 'Strikeouts')

# %% [markdown]
# In these there is no linear relationship between columns(walks,strikeouts).
# it had the ups and downs during the starting upto ending,but thw maximum walks happens(570) at 1500 Strikeouts.
# there is not have an any proper pattern to show it is in nearer to zig-zag manner.

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df,hue="Wins",palette="husl")

# %% [markdown]
# Above the pair plots of each of features. i can observe whether they are making good
# correlation or if they are just with out any pattern.
#
#
# In these we can infer the linear relationship between the features RunsAllowed and ERA,
# RunsAllowed and Earned Runs,EarnedRuns and ERA(Earned Runs Average).
#
# We have already been identified the outliers using boxplot.we have outliers in the columns'Runs',
# 'ERA','Shutouts','Saves','Errors'in which we need to remove the outliers.
# Let's remove them by using Zscore method.

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# ## Removing Outliers

# %% [markdown]
# ### 1.Zscore method

# %%
df.columns
# Out:
# Index(['Wins', 'Runs', 'At_Bats', 'Hits', 'Doubles', 'Triples', 'Home_Runs',
#        'Walks', 'Strikeouts', 'Stolen_Bases', 'Runs_Allowed', 'Earned_Runs',
#        'ERA', 'Complete_Games', 'Shutouts', 'Saves', 'Errors'],
#       dtype='object')

# %%
# Features containing outliers
features = df[['Runs','ERA','Shutouts','Saves','Errors']]

# %%
# using zscore to remove outliers
from scipy.stats import zscore
z=np.abs(zscore(features))

z
# Out:
# array([[0.61907797, 0.50695519, 0.81462859, 1.67160651, 0.46146963],
#        [0.13443166, 0.25459752, 0.1728    , 0.24987932, 0.60719689],
#        [0.33290586, 0.64134684, 0.32091429, 0.65485616, 1.11724227],
#        [1.14641931, 0.05301004, 0.56777144, 0.78410408, 0.48575751],
#        [0.01327008, 1.53131824, 0.1728    , 1.04259994, 0.60719689],
#        [3.50964704, 0.35016492, 0.32091429, 1.17184786, 0.46146963],
#        [1.31142984, 0.16500309, 1.80205719, 0.6376231 , 0.0971515 ],
#        [0.4286812 , 0.20980031, 0.32091429, 0.00861653, 1.26296953],
#        [0.76562578, 0.48455658, 0.1728    , 2.18859821, 0.04857575],
#        [1.03448909, 0.79216414, 0.32091429, 0.39636031, 0.194303  ],
#        [1.08641548, 0.63537388, 0.56777144, 0.24987932, 1.79730279],
#        [0.70562195, 0.86533293, 0.41965715, 0.52560823, 0.68006051],
#        [0.47137623, 0.03658439, 0.1728    , 0.37912725, 0.0971515 ],
#        [0.55792022, 0.45618501, 0.1728    , 0.24987932, 0.02428788],
# ...

# %% [markdown]
# now we have removed the outliers using Zscore

# %%
# creating new dataframe

df_new = df[(z<3).all(axis=1)]

df_new
# Out:
#     Wins  Runs  At_Bats  Hits  Doubles  Triples  Home_Runs  Walks  Strikeouts  \
# 0     95   724     5575  1497      300       42        139    383         973
# 1     83   696     5467  1349      277       44        156    439        1264
# 2     81   669     5439  1395      303       29        141    533        1157
# 3     76   622     5533  1381      260       27        136    404        1231
# 4     74   689     5605  1515      289       49        151    455        1259
# 6     87   764     5567  1397      272       19        212    554        1227
# 7     81   713     5485  1370      246       20        217    418        1331
# 8     80   644     5485  1383      278       32        167    436        1310
# 9     78   748     5640  1495      294       33        161    478        1148
# 10    88   751     5511  1419      279       32        172    503        1233
# 11    86   729     5459  1363      278       26        230    486        1392
# ...

# %%
# Checking the shape of new dataset
df_new.shape
# Out:
# (29, 17)

# %% [markdown]
# my new dataset contains 29 rows and 17 columns

# %%
# Checking the old data set
df.shape
# Out:
# (30, 17)

# %% [markdown]
# My old dataset contains 30 rows and 17 columns

# %%
# checking the data loss
data_loss =((30-29)/30*100)
data_loss
# Out:
# 3.3333333333333335

# %% [markdown]
# The data loss in zscore method after removing outliers is 3.33% which  is less than 10%.
# Still me have a look into IQR method

# %% [markdown]
# ### 2.IQR(Inter Quantile Range) method:

# %%
# 1st quantile
Q1=features.quantile(0.25)

#3rd quantile
Q3=features.quantile(0.75)

#IQR
IQR=Q3 - Q1

df1=df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df1.shape
# Out:
# (20, 17)

# %% [markdown]
# The new dataframe using IQR method has 20 rows and 17 columns after removing the outliers.

# %%
# checking shape of old dataset
df.shape
# Out:
# (30, 17)

# %%
# let's check the dataloss
data_loss = ((30-20)/30*100)

data_loss
# Out:
# 33.33333333333333

# %% [markdown]
# I can prefer to use the zscore method for removing outliers because their is huge data loss in
# IQR method which is equalivate to 10xzscore.
# so i want to stick with zscore method for removing outliers.

# %% [markdown]
# ### Checking for skewness:

# %%
# Checking the skewness
df_new.skew()
# Out:
# Wins              0.119013
# Runs             -0.215364
# At_Bats           0.169573
# Hits              0.783772
# Doubles          -0.335304
# Triples           0.090124
# Home_Runs         0.450862
# Walks             0.151193
# Strikeouts       -0.233815
# Stolen_Bases      0.494966
# Runs_Allowed      0.018155
# Earned_Runs       0.018461
# ERA               0.016693
# Complete_Games    0.854980
# Shutouts          0.526943
# Saves             0.627480
# Errors            0.840271
# dtype: float64

# %% [markdown]
# The Skewness present in the columns  are: "Hits","Complete_Games","Shutouts","Errors",and"Saves".

# %% [markdown]
# ### Removing Skewness using yeo-johnson method

# %%
skewed_features = ["Complete_Games","Shutouts","Saves","Errors"]

# %% [markdown]
# Taking all the columns with skewness as a list with variable skew_features

# %%
# using yeo-johnson method to remove the skewness
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''

parameters:
method = 'box=cox' or 'yeo-johnson'
'''
# Out:
# "\n\nparameters:\nmethod = 'box=cox' or 'yeo-johnson'\n"

# %%
df_new[skewed_features] = scaler.fit_transform(df_new[skewed_features].values)
df_new[skewed_features].head()
# Out:
#    Complete_Games  Shutouts     Saves    Errors
# 0       -0.307098 -0.787002  1.532753 -0.348265
# 1       -0.307098  0.236737  0.312020 -0.540820
# 2        2.011315 -0.252844 -0.664137 -1.326125
# 3        1.264463 -0.513555 -0.820689  0.650818
# 4        1.264463  0.236737 -1.149165 -0.540820

# %%
# Removing skewness in Hits using log1p
df_new["Hits"]=np.log1p(df_new["Hits"])

# %%
# Now let's check the skewness after using transformation
df_new.skew()
# Out:
# Wins              0.119013
# Runs             -0.215364
# At_Bats           0.169573
# Hits              0.738455
# Doubles          -0.335304
# Triples           0.090124
# Home_Runs         0.450862
# Walks             0.151193
# Strikeouts       -0.233815
# Stolen_Bases      0.494966
# Runs_Allowed      0.018155
# Earned_Runs       0.018461
# ERA               0.016693
# Complete_Games   -0.045947
# Shutouts          0.000529
# Saves            -0.000925
# Errors            0.065585
# dtype: float64

# %% [markdown]
# Now the skewness has been removed.let's visualize it.
#
# I have used all the methods to tremove the skewness in the columns"Hits" but the skewness not
# reducing in this column.After using yeo-johnson method i am getting zero values in the
# column"Hits" and showing NAN values while i plot the heat map.
# It is because the feature"Hits" might have some relation with the target and will remove
# this column if necessary in furthersteps.

# %%
# After removing let's check how the data has been distributed in each column.
features_skewed = ["Hits","Complete_Games","Shutouts","Saves","Errors"]
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df_new[features_skewed]:
    if plotnumber<=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.distplot(new_df[column],color='g')
        plt.xlabel(column,fontsize=25)
    plotnumber+=1
plt.show()

# %% [markdown]
# After see the data is normally distributed and skewness is also removed. I used all the
# possible methods to remove the skewness but the column"Hits"still has skewness.
# first we will check the correlation with the target,if there is necessary will drop this column

# %% [markdown]
# #### Correlation between the target variable and independent variables using Heat map

# %%
# checking  the correlation between features and the target

cor = df_new.corr()

cor
# Out:
#                     Wins      Runs   At_Bats      Hits   Doubles   Triples  \
# Wins            1.000000  0.390451 -0.085780 -0.020785  0.384886 -0.206737
# Runs            0.390451  1.000000  0.438022  0.432236  0.469293  0.134204
# At_Bats        -0.085780  0.438022  1.000000  0.770154  0.490752  0.445604
# Hits           -0.020785  0.432236  0.770154  1.000000  0.527354  0.579735
# Doubles         0.384886  0.469293  0.490752  0.527354  1.000000  0.342419
# Triples        -0.206737  0.134204  0.445604  0.579735  0.342419  1.000000
# Home_Runs       0.245697  0.586894 -0.064653 -0.219201 -0.098695 -0.369299
# Walks           0.447513  0.258450 -0.137850 -0.221773  0.211243 -0.404852
# Strikeouts      0.156469  0.081158 -0.111243 -0.373301 -0.096772 -0.196586
# Stolen_Bases   -0.169503  0.075323  0.373674  0.420199  0.194308  0.483818
# Runs_Allowed   -0.823176 -0.013858  0.315499  0.243639 -0.215196  0.312750
# ...

# %% [markdown]
# This gives the correlation between the dependent and independent variables.
# we can visualize by plotting heat map.

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df_new.corr(),linewidths=.1,fmt='0.2f',cmap="Greens_r",annot=True)
plt.yticks(rotation=0);

# %% [markdown]
# The heat map contains both postive(+) and neagative(-) correlation
# * The target"Wins" is postively correlated with the features "Saves","Shutouts","Walks","HomeRuns",
#   "Doubles","Runs","Strikeouts".
# * The target"Wins" is highly negatively correlated with the feature"ERA","Earned_Runs",
#    and "Runs_Allowed".
# *The label "Wins" is also negatively correlated with the features"Errors","Stolen_Bases","Triples"
#    and "At_Bats".
# * Apart form this label  and feature relation we can also see that the features"ERA","Earned_Runs" and "Runs_Allowed" are highly positively correlated with each other. which causes multicollinearity problem,to avoid this problem will check VIF value and will drop the columns if necessary.
#
#     The Columns "Hits" and "Complete-Games" has no correlation with the label,we can drop these columns.

# %%
cor['Wins'].sort_values(ascending=False)
# Out:
# Wins              1.000000
# Saves             0.756713
# Shutouts          0.481626
# Walks             0.447513
# Runs              0.390451
# Doubles           0.384886
# Home_Runs         0.245697
# Strikeouts        0.156469
# Complete_Games    0.007696
# Hits             -0.020785
# Errors           -0.079633
# At_Bats          -0.085780
# Stolen_Bases     -0.169503
# Triples          -0.206737
# Earned_Runs      -0.815308
# Runs_Allowed     -0.823176
# ERA              -0.826952
# Name: Wins, dtype: float64

# %% [markdown]
# #### positively correlated

# %% [markdown]
# * Saves
# *Shutouts
# *Walks
# *Runs
# *Doubles
# *Home_Runs
# *Strikeouts
# *Complete_Games

# %% [markdown]
# #### negatively correlated

# %% [markdown]
# * Home
# * Errors
# * At_Bats
# * Stolen_Bases
# * Triples
# * Earned_Runs
# * Runs_Allowed
# * ERA(Earned Runs Allowed)

# %% [markdown]
# # Visualizing the correlation

# %%
# visualizing the correlation between label and features using bar plot
plt.figure(figsize=(25,10))
df_new.corr()['Wins'].sort_values(ascending=False).drop(['Wins']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel(' target names',fontsize=14)
plt.title('correlation between label and feature using bar plot',fontsize=18)
plt.show()

# %% [markdown]
# Now we can easily analyse the data, here "Hits" and "Complete_Games" are very less correlated with target column. let's drop them.

# %%
df_new.drop("Hits",axis=1, inplace=True)

# %%
df_new.drop("Complete_Games",axis=1, inplace=True)

# %%
df_new.head()
# Out:
#    Wins  Runs  At_Bats  Doubles  Triples  Home_Runs  Walks  Strikeouts  \
# 0    95   724     5575      300       42        139    383         973
# 1    83   696     5467      277       44        156    439        1264
# 2    81   669     5439      303       29        141    533        1157
# 3    76   622     5533      260       27        136    404        1231
# 4    74   689     5605      289       49        151    455        1259
#
#    Stolen_Bases  Runs_Allowed  Earned_Runs   ERA  Shutouts     Saves    Errors
# 0           104           641          601  3.73 -0.787002  1.532753 -0.348265
# 1            70           700          653  4.07  0.236737  0.312020 -0.540820
# 2            86           640          584  3.67 -0.252844 -0.664137 -1.326125
# 3            68           701          643  3.98 -0.513555 -0.820689  0.650818
# 4            83           803          746  4.64  0.236737 -1.149165 -0.540820

# %% [markdown]
# This is the data set after droping less correlated columns.

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ## Separating the independent and target variables into x and y

# %%
x= df_new.drop("Wins",axis=1)
y= df_new["Wins"]

# %% [markdown]
# Here we have separted the target variable and independent variable.

# %%
x.shape
# Out:
# (29, 14)

# %%
y.shape
# Out:
# (29,)

# %%
x.head()
# Out:
#    Runs  At_Bats  Doubles  Triples  Home_Runs  Walks  Strikeouts  \
# 0   724     5575      300       42        139    383         973
# 1   696     5467      277       44        156    439        1264
# 2   669     5439      303       29        141    533        1157
# 3   622     5533      260       27        136    404        1231
# 4   689     5605      289       49        151    455        1259
#
#    Stolen_Bases  Runs_Allowed  Earned_Runs   ERA  Shutouts     Saves    Errors
# 0           104           641          601  3.73 -0.787002  1.532753 -0.348265
# 1            70           700          653  4.07  0.236737  0.312020 -0.540820
# 2            86           640          584  3.67 -0.252844 -0.664137 -1.326125
# 3            68           701          643  3.98 -0.513555 -0.820689  0.650818
# 4            83           803          746  4.64  0.236737 -1.149165 -0.540820

# %% [markdown]
# The dataset contains all are indpendent variables.

# %% [markdown]
# # Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x= pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#         Runs   At_Bats   Doubles   Triples  Home_Runs     Walks  Strikeouts  \
# 0   0.959398  0.830084  1.556538  1.010845  -0.765863 -1.536359   -2.727623
# 1   0.331147 -0.702831  0.201171  1.208917  -0.181389 -0.495021    0.121896
# 2  -0.274666 -1.100253  1.733325 -0.276617  -0.697101  1.252941   -0.925866
# 3  -1.329231  0.233951 -0.800621 -0.474688  -0.869006 -1.145857   -0.201246
# 4   0.174084  1.255894  0.908319  1.704094  -0.353293 -0.197495    0.072935
# 5   1.856900  0.716535 -0.093474 -1.266972   1.743939  1.643442   -0.240414
# 6   0.712585 -0.447345 -1.625627 -1.167936   1.915843 -0.885522    0.777970
# 7  -0.835605 -0.447345  0.260100  0.020490   0.196801 -0.550807    0.572335
# 8   1.497899  1.752672  1.202964  0.119526  -0.009484  0.230197   -1.013995
# 9   1.565212 -0.078310  0.319029  0.020490   0.368705  0.695081   -0.181661
# 10  1.071586 -0.816380  0.260100 -0.573723   2.362794  0.378960    1.375292
# ...

# %% [markdown]
# That's our scaled data using standard scaler.

# %% [markdown]
# ## Checking VIF values to solve Multicollinearity

# %%
# Finding varaiance inflation factor in each scaled column i.e, x.shape[1] (1/(1-R2))

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i) 
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# let's check the values
vif
# Out:
#      VIF values      Features
# 0      6.219825          Runs
# 1      9.828077       At_Bats
# 2      2.683572       Doubles
# 3      3.196853       Triples
# 4      7.369072     Home_Runs
# 5      2.686472         Walks
# 6      2.741072    Strikeouts
# 7      1.757901  Stolen_Bases
# 8    179.096825  Runs_Allowed
# 9   1754.643859   Earned_Runs
# 10  1310.260128           ERA
# 11     3.086344      Shutouts
# 12     4.021573         Saves
# 13     1.742105        Errors

# %% [markdown]
# The VIF value is more than 10 in the columns "At_BAts","Runs_Allowed","Earned_Runs","ERA".
# Let's drop these one by one.
# Fisrt drop the column having highest VIF value that is "Earned_Runs".

# %%
x.drop("Earned_Runs",axis=1, inplace=True)

# %%
# Againing checking the VIF after removing one column
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
                for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#     VIF values      Features
# 0     4.352902          Runs
# 1     3.177214       At_Bats
# 2     2.597985       Doubles
# 3     3.072775       Triples
# 4     4.949255     Home_Runs
# 5     2.561982         Walks
# 6     2.661842    Strikeouts
# 7     1.680467  Stolen_Bases
# 8   119.939744  Runs_Allowed
# 9   111.859162           ERA
# 10    2.932319      Shutouts
# 11    2.112465         Saves
# 12    1.742101        Errors

# %% [markdown]
# Now we can see the multicollinearity still exists, so let me drop the column "Runs_Allowed".

# %%
x.drop("Runs_Allowed", axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
                for i in range(len(x.columns))]
vif["Features"] = x.columns

# let's check the values
vif
# Out:
#     VIF values      Features
# 0     4.250076          Runs
# 1     2.238746       At_Bats
# 2     2.597917       Doubles
# 3     3.030073       Triples
# 4     4.562014     Home_Runs
# 5     2.222720         Walks
# 6     2.042786    Strikeouts
# 7     1.568151  Stolen_Bases
# 8     3.878177           ERA
# 9     2.651314      Shutouts
# 10    1.954370         Saves
# 11    1.493128        Errors

# %% [markdown]
# Now the multicollinearity issue solved.

# %%
 # dataset after preprocessing
x.head()
# Out:
#        Runs   At_Bats   Doubles   Triples  Home_Runs     Walks  Strikeouts  \
# 0  0.959398  0.830084  1.556538  1.010845  -0.765863 -1.536359   -2.727623
# 1  0.331147 -0.702831  0.201171  1.208917  -0.181389 -0.495021    0.121896
# 2 -0.274666 -1.100253  1.733325 -0.276617  -0.697101  1.252941   -0.925866
# 3 -1.329231  0.233951 -0.800621 -0.474688  -0.869006 -1.145857   -0.201246
# 4  0.174084  1.255894  0.908319  1.704094  -0.353293 -0.197495    0.072935
#
#    Stolen_Bases       ERA  Shutouts     Saves    Errors
# 0      0.905953 -0.511388 -0.787002  1.532753 -0.348265
# 1     -0.585315  0.238952  0.236737  0.312020 -0.540820
# 2      0.116458 -0.643801 -0.252844 -0.664137 -1.326125
# 3     -0.673037  0.040333 -0.513555 -0.820689  0.650818
# 4     -0.015124  1.496876  0.236737 -1.149165 -0.540820

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Finding best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import LinearRegression
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30, random_state=i)
    mod = LinearRegression()
    mod.fit(x_train, y_train)
    pred = mod.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is ",maxAccu," on Random_state ",maxRS)
# Out:
# Maximum r2 score is  0.9291790579976077  on Random_state  50

# %% [markdown]
# It is getting the maximum R2 score as 92% on the random state50.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRS)

# %% [markdown]
# I am creating new test train splits

# %% [markdown]
# # Regressions Algorithms

# %%
from sklearn.linear_model import LinearRegression, Lasso,Ridge
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %% [markdown]
# ## 1. Linear Regression

# %%
# Checking r2score for Linear Regression
LR = LinearRegression()
LR.fit(x_train,y_train)

# prediction
predLR=LR.predict(x_test)
print('R2_score:',r2_score(y_test,predLR))

# Mean Absolute Error (MAE)
print('MAE:',metrics.mean_absolute_error(y_test, predLR))

# Mean Squared Error (MSE)
print('MSE:',metrics.mean_squared_error(y_test, predLR))

# Root Mean Squared Error (RMSE)
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predLR)))
# Out:
# R2_score: 0.9291790579976077
# MAE: 2.4627865987898443
# MSE: 10.163242343651952
# RMSE: 3.187984056367276

# %% [markdown]
# The R2 score value for Linear Regression model is 92.91%.

# %% [markdown]
# ## 2.Ridge Regression:

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
paramsRidge = {'alpha':[0.01, 0.1, 1.0,10.26], 'solver' : ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']}
ridge=Ridge()
clf=GridSearchCV(ridge,paramsRidge)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10.26, 'solver': 'svd'}

# %%
# Checking R2 score for Ridge regressor
ridge=Ridge(alpha=10.26,solver='sag')
ridge.fit(x_train,y_train)
ridge.score(x_train,y_train)
pred_ridge=ridge.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_ridge))
print('MAE:',metrics.mean_absolute_error(y_test, pred_ridge))
print('MSE:',metrics.mean_squared_error(y_test, pred_ridge))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, pred_ridge)))
# Out:
# R2_Score: 0.8226011110226229
# MAE: 4.389487366538268
# MSE: 25.45783562312384
# RMSE: 5.045575846533659

# %% [markdown]
# The R2 score for Ridge Regressor is 82%.

# %% [markdown]
# ## 3.Lasso Regressor:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
lasso=Lasso()
clf=GridSearchCV(lasso,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
lasso=Lasso(alpha=1,random_state=0)
lasso.fit(x_train,y_train)
lasso.score(x_train,y_train)
pred_lasso=lasso.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_lasso))
print('MAE:',metrics.mean_absolute_error(y_test, pred_lasso))
print('MSE:',metrics.mean_squared_error(y_test, pred_lasso))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_Score: 0.8642951302468397
# MAE: 3.8253497504300973
# MSE: 19.4744864939597
# RMSE: 4.41299065192299

# %% [markdown]
# The R2 Score using Lasso Regressor  is 86%.

# %% [markdown]
# ## 4. Stochastic Gradient Descent Regressor

# %%
# checking R2 score for Stochastic Gradient Descent Regressor
SGD=SGDRegressor()
SGD.fit(x_train,y_train)

# prediction
predSGD=SGD.predict(x_test)
print('R2_Score:',r2_score(y_test,predSGD))
print('MAE:',metrics.mean_absolute_error(y_test, predSGD))
print('MSE:',metrics.mean_squared_error(y_test, predSGD))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predSGD)))
# Out:
# R2_Score: 0.9291361258208032
# MAE: 2.758131089591793
# MSE: 10.169403376036831
# RMSE: 3.1889501996796423

# %% [markdown]
# # Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
# checking cv score for Linear Regression
print(cross_val_score(LR,x,y,cv=5).mean())
# Out:
# 0.37344412304899344

# %%
# checking cv score for Ridge Regression
print(cross_val_score(ridge,x,y,cv=5).mean())
# Out:
# 0.3491490643170511

# %%
# checking cv score for Lasso Regressor
print(cross_val_score(lasso,x,y,cv=5).mean())
# Out:
# 0.5206537019436117

# %%
# checking cv score for SGD Regression
print(cross_val_score(SGD,x,y,cv=5).mean())
# Out:
# 0.2647234744669612

# %% [markdown]
# The difference between model accuracy and cross validation score is less for lasso
# So Lasso Regressor is best fitting model

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Lasso Regressor
parameters = {'alpha':[0.01, 0.1, 1.0,10.26],
              'selection':['cyclic','random'],
              'max_iter':[2,4,6,8,10],
              'tol':[100,1000],
              'fit_intercept':['bool']}

# %%
GCV=GridSearchCV(Lasso(),parameters,cv=5)

# %% [markdown]
# Running GridSearchCV for the model lasso

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'fit_intercept': ['bool'],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
 GCV.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': 'bool',
#  'max_iter': 4,
#  'selection': 'random',
#  'tol': 100}

# %% [markdown]
# This gives the best parameter value.

# %%
# Creating final model
Baseball = Lasso(alpha=1.0, fit_intercept='bool', max_iter=2, selection="random", tol=100)
Baseball.fit(x_train, y_train)
pred = Baseball.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_lasso)*100)
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test, pred_lasso)))
# Out:
# R2_Score: 86.42951302468397
# RMSE value: 4.41299065192299

# %% [markdown]
# After tuning it is getting R2 score as 86.42% for out best model

# %% [markdown]
# # Saving the model

# %%
# Saving the model using .pkl
import joblib
joblib.dump(Baseball,"Baseball_Case_Study.pkl")
# Out:
# ['Baseball_Case_Study.pkl']

# %% [markdown]
# I have saved my model using joblib.

# %% [markdown]
# # Predictions:

# %%
# Loading the saved model
model=joblib.load("Baseball_Case_Study.pkl ")

# Prediction 
prediction = model.predict(x_test)
prediction
# Out:
# array([76.80993533, 85.24632249, 74.56622147, 86.43548708, 76.47525592,
#        69.97382944, 84.63335965, 88.92451576, 91.53432387])

# %% [markdown]
# These are predicted values

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                    0          1          2          3          4          5  \
# Predicted  76.809935  85.246322  74.566221  86.435487  76.475256  69.973829
# Original   68.000000  78.000000  74.000000  88.000000  68.000000  64.000000
#
#                   6          7           8
# Predicted  84.63336  88.924516   91.534324
# Original   92.00000  90.000000  100.000000

# %% [markdown]
# both original and predicted values are almost equal.

# %% [markdown]
# ### COMPLETED THE BASEBALLCASE STUDY
